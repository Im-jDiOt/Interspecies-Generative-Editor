# %% [markdown]
# ### torchao version 호환성 해결

# %%
# First, uninstall the existing torchao package
# !pip uninstall -y torchao

# Then, install the specific version 0.16.0
# !pip install torchao==0.16.0

# After this, you should restart the Colab runtime (Runtime -> Restart runtime)
# and then re-run the cells from the beginning to ensure the new version is loaded.
# Out:
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 55.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# After restarting the runtime, please execute the following cell to confirm the `torchao` version.

# %%
import torchao
torchao.__version__
# Out:
# '0.16.0'

# %%
ROOT = '/content/drive/MyDrive/generative_editing'
# %cd {ROOT}
# !pwd
# Out:
# /content/drive/MyDrive/generative_editing
# /content/drive/MyDrive/generative_editing

# %%
# !pip install -r /content/drive/MyDrive/generative_editing/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 15.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 119.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 98.2 MB/s eta 0:00:00
# ...
#   Created wheel for insightface: filename=insightface-0.7.3-cp312-cp312-linux_x86_64.whl size=1071483 sha256=3c8745bfc6d2118e8d647490065ebe49cfc002e975e4875efa3f72080d8668c6
#   Stored in directory: /root/.cache/pip/wheels/73/3c/e2/6d4815e8a8b33a2006554d65ce0d1f973e768f4c7a222fa675
# Successfully built insightface
# ...
#   Attempting uninstall: absl-py
# ...

# %%
# !python scripts/setup_models.py
# Out:
# [fetch] StableDiffusionPipeline: runwayml/stable-diffusion-v1-5
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:189: UserWarning: The `resume_download` argument is deprecated and ignored in `snapshot_download`. Downloads always resume whenever possible.
#   warnings.warn(
# ...
# Fetching 36 files: 100% 36/36 [21:49<00:00, 36.38s/it]
# Download complete: : 47.3GB [21:49, 69.2MB/s]              [fetch] IP-Adapter-FaceID weights: h94/IP-Adapter-FaceID
#
# ...
#
# Fetching 21 files:   0% 0/21 [00:00<?, ?it/s]
# ...
#
# Fetching 21 files:   5% 1/21 [00:00<00:03,  6.66it/s]
# ...
#
# Fetching 21 files:  19% 4/21 [00:00<00:03,  4.35it/s]
# ...
# Download complete: : 47.3GB [22:03, 69.2MB/s]
# ...
#
# Fetching 21 files:  29% 6/21 [00:29<01:36,  6.40s/it]
# ...
#
# Fetching 21 files: 100% 21/21 [01:50<00:00,  5.26s/it]
#
# Download complete: : 5.77GB [01:50, 123MB/s]              [fetch] CLIP-ViT-H (image encoder for FaceID-Plus, optional): laion/CLIP-ViT-H-14-laion2B-s32B-b79K
#
#
# ...
#
#
# ...

# %%
# !python scripts/prepare_faces.py --in data/faces/raw --out data/faces/aligned
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# ...

# %%
# !ls data/faces/aligned/
# Out:
# 1741765478663640.npy	  413406_507584_454.npy
# 1741765478663640.png	  413406_507584_454.png
# 20160221014453.npy	  41776_13965_3335.npy
# 20160221014453.png	  41776_13965_3335.png
# 202506241445021510_1.npy  91ae138254444a9412dc172912aeee52.npy
# 202506241445021510_1.png  91ae138254444a9412dc172912aeee52.png

# %%
# !pip uninstall diffusers
# !pip install diffusers==0.26.3
# Out:
# Found existing installation: diffusers 0.37.1
# Uninstalling diffusers-0.37.1:
#   Would remove:
#     /usr/local/bin/diffusers-cli
#     /usr/local/lib/python3.12/dist-packages/diffusers-0.37.1.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/diffusers/*
# Proceed (Y/n)? y
#   Successfully uninstalled diffusers-0.37.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.6 MB/s eta 0:00:00

# %%
# 한 장
# !python scripts/run_sweep.py --config configs/stage2_ipadapter.yaml --limit 30
# Out:
# faces=6  combos=30  total=180
# --limit 30 -> running 30
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading pipeline components...:  67% 4/6 [00:12<00:07,  3.79s/it]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 833.69it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 731.35it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 1196.32it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 965.43it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...

# %%
# 전체
# !python scripts/run_sweep.py --config configs/stage2_ipadapter.yaml
# Out:
# faces=6  combos=30  total=180
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 10230.01it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 5440.08it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 5014.11it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 4211.15it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...
